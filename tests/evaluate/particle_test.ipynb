# %%
import torch
import sys
sys.path.append('../..')

# %%
from torchuq.evaluate import particle

preds = torch.randn(100, 50) + torch.linspace(0, 1, 100).view(-1, 1)
labels = torch.zeros(100)

# %%
particle.plot_particle_sequence(preds, labels);

# %%
particle.plot_particle_trend(preds, labels);
particle.plot_particle_trend(preds, labels, smooth_bw=5); 
particle.plot_particle_trend(preds, labels, smooth_bw=10);

# %%
plt
